# %%
from selenium import webdriver
import time
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import os

count=0
# Khởi tạo trình duyệt
s = Service('C:/Users/win/Downloads/khdl/CuoiKi/chromedriver_win32/chromedriver.exe')
driver = webdriver.Chrome(service=s)
driver.get("https://www.booking.com/index.vi.html")
time.sleep(5)
close_pane = driver.find_element(By.CSS_SELECTOR,"[aria-label='Bỏ qua phần đăng nhập.']")
close_pane.click()
time.sleep(0.5)

date_starts = ['2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25', '2023-05-26', '2023-05-27']
date_ends = ['2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28']
for d in range(0,7):
# Mở trang web booking.com
    driver.get("https://www.booking.com/index.vi.html")

    time.sleep(5)

    # tạo mảng serch_input


    # bỏ qua phần đăng nhập 

   


    # Tìm thẻ input để nhập địa điểm
    search_input = driver.find_element(By.NAME,"ss")
    # Nhập địa điểm "Paris" vào ô tìm kiếm
    hotel_country = "Viet Nam"
    hotel_place = "Hà Nội"
    search_input.send_keys(hotel_place)
    time.sleep(0.5)


# date_starts = ['2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25', '2023-05-26', '2023-05-27']
# date_ends = ['2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28']
# for d in range(1,8):
# date_starts = driver.find_elements(By.CSS_SELECTOR,"[data-testid='property-card']")
# print(len(date_starts))

# Tìm thẻ input để nhập ngày check-in và check-out
# nhập bắt đầu kết thúc

    
    date_start = driver.find_element(By.CSS_SELECTOR,"[data-testid='date-display-field-start']")
    date_start.click()
    time.sleep(0.5)

#     checkin_input = driver.find_element(By.CSS_SELECTOR,"[data-date='2023-05-30']")
#     checkin_input = driver.find_element(By.CSS_SELECTOR,"[data-date='{date_starts[d]}]")
    checkin_input = driver.find_element(By.CSS_SELECTOR, f"[data-date='{date_starts[d]}']")

    checkin_input.click()
    time.sleep(0.5)

    # date_end = driver.find_element(By.CSS_SELECTOR,"[data-testid='date-display-field-end']")
    # date_end.click()

#     checkin_output = driver.find_element(By.CSS_SELECTOR,"[data-date='2023-05-31']")
#     checkin_output = driver.find_element(By.CSS_SELECTOR,"[data-date='{date_ends[index]}']")
    checkin_output = driver.find_element(By.CSS_SELECTOR, f"[data-date='{date_ends[d]}']")


    checkin_output.click()
    time.sleep(0.5)

    # Tìm thẻ button để tìm kiếm
    search_button = driver.find_element(By.CSS_SELECTOR,'.fc63351294.a822bdf511.d4b6b7a9e7.cfb238afa1.c938084447.f4605622ad.aa11d0d5cd')
    # Kích hoạt button để tìm kiếm
    search_button.click()
    time.sleep(0.5)

    list_hotel = []
    for i in range(1,10): 
        time.sleep(5)
        # lấy các div chứa thông tin khách sạn
        hotel_infos = driver.find_elements(By.CSS_SELECTOR,"[data-testid='property-card']")
        print(len(hotel_infos))
        for hotel_info in hotel_infos:
            hotel_name = hotel_info.find_element(By.CSS_SELECTOR,"[data-testid='title']").text
            hotel_price = hotel_info.find_element(By.CSS_SELECTOR,"[data-testid='price-and-discounted-price']").text
            hotel_tax = hotel_info.find_element(By.CSS_SELECTOR,"[data-testid='taxes-and-charges']").text
            hotel_stars = len(hotel_info.find_element(By.CSS_SELECTOR,"[data-testid='rating-stars']").find_elements(By.TAG_NAME,"span")) if len(hotel_info.find_elements(By.CSS_SELECTOR,"[data-testid='rating-stars']"))!=0 else None
            hotel_distance = hotel_info.find_element(By.CSS_SELECTOR,"[data-testid='distance']").text if len(hotel_info.find_elements(By.CSS_SELECTOR,"[data-testid='distance']"))!=0 else None 
            hotel_number_review = hotel_info.find_element(By.CSS_SELECTOR,".d8eab2cf7f.c90c0a70d3.db63693c62").text if len(hotel_info.find_elements(By.CSS_SELECTOR,".d8eab2cf7f.c90c0a70d3.db63693c62"))!=0 else None
            hotel_sustainable_level = hotel_info.find_element(By.CSS_SELECTOR,".d8eab2cf7f.be09c104ad").text if len(hotel_info.find_elements(By.CSS_SELECTOR,".d8eab2cf7f.be09c104ad"))!=0 else None
            hotel_discount = "Ưu Đãi Mùa Du Lịch" in hotel_info.text
            hotel_point = hotel_info.find_element(By.CSS_SELECTOR,".b5cd09854e.d10a6220b4").text if len(hotel_info.find_elements(By.CSS_SELECTOR,".b5cd09854e.d10a6220b4"))!=0 else None
            hotel_free_breakfast = "Bao bữa sáng" in hotel_info.text
            hotel_is_prepayment = "Không cần thanh toán trước" in hotel_info.text
            hotel_is_notable_place = "Nổi bật" in hotel_info.text
            hotel_is_free_cancel = ("Miễn phí hủy" in hotel_info.text) or ("Miễn Phí hủy phòng" in hotel_info.text)
            hotel_is_sold_out = "phòng với giá này trên trang của chúng tôi" in hotel_info.text

            print("hotel_info: ",hotel_info.text)
            # print("hotel_name: ",hotel_name, end=" | ")
            # print("hotel_price: ",hotel_price, end=" | ")
            # print("hotel_tax: ",hotel_tax, end=" | ")
            # print("hotel_stars: ",hotel_stars, end=" | ")
            # print("hotel_distance: ",hotel_distance, end=" | ")
            # print("hotel_number_review: ",hotel_number_review, end=" | ")
            # print("hotel_sustainable_level: ",hotel_sustainable_level, end=" | ")
            # print("hotel_discount: ",hotel_discount, end=" | ")
            # print("hotel_point: ",hotel_point)

            list_hotel.append([hotel_country,hotel_place,hotel_name,hotel_price,hotel_tax,hotel_stars,
                               hotel_distance,hotel_number_review,hotel_sustainable_level,
                               hotel_discount,hotel_free_breakfast,hotel_is_prepayment,
                               hotel_is_notable_place,hotel_is_free_cancel,hotel_is_sold_out,hotel_point])
            count=count+1
            print('-----------------',count,'--------------------')
        try:
            page_index_button = driver.find_element(By.CSS_SELECTOR,f"[aria-label=' {i+1}']")
            page_index_button.click()
        except:
            break
    df_hotel = pd.DataFrame(list_hotel, columns=['Country','Place', 'Name', 'Price', 'Tax', 
                                             'Stars', 'Distance', 'Number_of_review', 
                                             'Sustainable_level', 'Discount',
                                             'Free_Breakfast', 'is_Prepayment',
                                             'is_NotablePlace', 'is_Free_Cancel',
                                             'is_Sold_Out', 'Point'])
#     df_hotel.to_csv('hotel_test.csv', index=False, encoding='utf-8-sig')
    df_hotel.to_csv('hotel_test.csv', mode='a', index=False, encoding='utf-8-sig', header=not os.path.isfile('hotel_test.csv'))

    
# Đóng trình duyệt
driver.quit()

# print(list_hotel)
# Đọc file CSV vào DataFrame
# df = pd.read_csv('hotel_foreign.csv')
# df_hotel = pd.DataFrame(list_hotel, columns=['Country','Place', 'Name', 'Price', 'Tax', 
#                                              'Stars', 'Distance', 'Number_of_review', 
#                                              'Sustainable_level', 'Discount',
#                                              'Free_Breakfast', 'is_Prepayment',
#                                              'is_NotablePlace', 'is_Free_Cancel',
#                                              'is_Sold_Out', 'Point'])
# # df_new = pd.concat([df, df_hotel], ignore_index=True)0
# df_hotel.to_csv('hotel_test.csv', index=False, encoding='utf-8-sig')
# Out:
# 25
# hotel_info:  Sun Clover Boutique Hotel
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 3,2km
# Chỗ nghỉ Du lịch Bền vững
# 8,3
# Rất tốt
# 8 đánh giá
# Mới trên Booking.com
# Ưu Đãi Trong Thời Gian Có Hạn
# Phòng Tiêu Chuẩn Có Giường Cỡ Queen
# 1 giường đôi lớn
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 643.500VND 437.580
# Giá gốc là VND 643.500. Giá hiện tại là VND 437.580.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1 --------------------
# hotel_info:  Hanoi Center Silk Classic Hotel & Travel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# Chỗ nghỉ Du lịch Bền vững
# 8,8
# Tuyệt vời
# 915 đánh giá
# Địa điểm 9,4
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Có Giường Cỡ King
# 1 giường đôi cực lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 4.118.400VND 658.944
# Giá gốc là VND 4.118.400. Giá hiện tại là VND 658.944.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 2 --------------------
# hotel_info:  Bao bữa sáng
# Golden Sail Hotel & Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# 8,7
# Tuyệt vời
# 686 đánh giá
# Địa điểm 9,5
# Phòng Superior Giường Đôi
# 1 giường đôi
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 2.125.000VND 1.062.500
# Giá gốc là VND 2.125.000. Giá hiện tại là VND 1.062.500.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 3 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi L'Heritage Diamond Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 250m
# Chỗ nghỉ Du lịch Bền vững
# 9,0
# Tuyệt hảo
# 1.073 đánh giá
# Địa điểm 9,6
# Phòng Superior Có Giường Cỡ Queen
# 1 giường đôi hoặc 2 giường đơn
# Bao bữa sáng
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 3.150.000VND 1.417.500
# Giá gốc là VND 3.150.000. Giá hiện tại là VND 1.417.500.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 4 --------------------
# hotel_info:  Lucky Central Hotel & Travel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 500m
# Chỗ nghỉ Du lịch Bền vững
# 8,2
# Rất tốt
# 26 đánh giá
# Địa điểm 9,6
# Mới trên Booking.com
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 6 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.625.000VND 577.500
# Giá gốc là VND 2.625.000. Giá hiện tại là VND 577.500.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 5 --------------------
# hotel_info:  22Land Residence Hotel & Spa 52 Ngo Huyen
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 450m
# 8,1
# Rất tốt
# 454 đánh giá
# Suite có Ban công.
# 1 suite riêng tư • 1 phòng ngủ • 1 phòng khách • 1 phòng tắm • 32m²
# 2 giường (1 giường sofa, 1 giường đôi lớn)
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 3 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 777.600VND 699.840
# Giá gốc là VND 777.600. Giá hiện tại là VND 699.840.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 6 --------------------
# hotel_info:  Hanoi Paradise hotel & Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,7km
# 8,5
# Rất tốt
# 1.372 đánh giá
# Địa điểm 9,4
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 4.000.000VND 600.000
# Giá gốc là VND 4.000.000. Giá hiện tại là VND 600.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 7 --------------------
# hotel_info:  Bao bữa sáng
# Golden Villa Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 350m
# Chỗ nghỉ Du lịch Bền vững
# 8,0
# Rất tốt
# 347 đánh giá
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 997.500VND 798.000
# Giá gốc là VND 997.500. Giá hiện tại là VND 798.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 8 --------------------
# hotel_info:  Bao bữa sáng
# Beryl Palace Hotel and Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# Chỗ nghỉ Du lịch Bền vững
# 8,6
# Tuyệt vời
# 695 đánh giá
# Địa điểm 9,3
# Ưu Đãi Mùa Du Lịch
# Phòng Superior Giường Đôi/2 Giường Đơn
# Nhiều loại giường
# Bao bữa sáng
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 7 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 3.600.000VND 900.000
# Giá gốc là VND 3.600.000. Giá hiện tại là VND 900.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 9 --------------------
# hotel_info:  Hanoi Center Silk Hotel & Travel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,7km
# Chỗ nghỉ Du lịch Bền vững
# 8,9
# Tuyệt vời
# 1.935 đánh giá
# Địa điểm 9,4
# Ưu Đãi Mùa Du Lịch
# Phòng Superior
# Nhiều loại giường
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 5.600.000VND 1.176.000
# Giá gốc là VND 5.600.000. Giá hiện tại là VND 1.176.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 10 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi Paradise Center Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 500m
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 2.704 đánh giá
# Địa điểm 9,3
# Ưu Đãi Trong Thời Gian Có Hạn
# Phòng Deluxe 1 Giường đôi hoặc 2 Giường đơn với Cửa sổ
# 1 giường đôi hoặc 2 giường đơn
# Bao bữa sáng
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 5 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 3.403.225VND 952.903
# Giá gốc là VND 3.403.225. Giá hiện tại là VND 952.903.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 11 --------------------
# hotel_info:  The Flower Boutique Hotel & Travel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 1,7km
# Chỗ nghỉ Du lịch Bền vững
# 9,3
# Tuyệt hảo
# 326 đánh giá
# Địa điểm 9,3
# Phòng Deluxe Giường Đôi
# 1 giường đôi cực lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 6 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.380.000VND 880.600
# Giá gốc là VND 2.380.000. Giá hiện tại là VND 880.600.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 12 --------------------
# hotel_info:  Hanoi Media Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 500m
# 8,7
# Tuyệt vời
# 1.031 đánh giá
# Địa điểm 9,6
# Phòng Superior Giường Đôi
# 1 giường đôi hoặc 2 giường đơn
# 1 đêm, 2 người lớn
# VND 1.066.649
# Giá là VND 1.066.649
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 13 --------------------
# hotel_info:  Madelise Palace Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# Chỗ nghỉ Du lịch Bền vững
# 9,2
# Tuyệt hảo
# 92 đánh giá
# Địa điểm 9,7
# Mới trên Booking.com
# Phòng Superior Giường Đôi
# 1 giường đôi
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.070.000VND 621.000
# Giá gốc là VND 2.070.000. Giá hiện tại là VND 621.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 14 --------------------
# hotel_info:  Bao bữa sáng
# Classy Holiday Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# 8,4
# Rất tốt
# 690 đánh giá
# Địa điểm 9,4
# Phòng Cổ Điển Giường Đôi/2 Giường Đơn
# Nhiều loại giường
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 818.171
# Giá là VND 818.171
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 15 --------------------
# hotel_info:  Alisa Hotel & Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,5km
# Chỗ nghỉ Du lịch Bền vững
# 8,3
# Rất tốt
# 407 đánh giá
# Suite có Ban công.
# 1 suite riêng tư
# 1 giường đôi lớn
# Chỉ còn 1 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 3.690.000VND 959.400
# Giá gốc là VND 3.690.000. Giá hiện tại là VND 959.400.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 16 --------------------
# hotel_info:  Bao bữa sáng
# Flora Centre Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,7km
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 931 đánh giá
# Địa điểm 9,7
# Phòng Deluxe Giường Đôi
# 1 giường đôi cực lớn
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 2.565.000VND 923.400
# Giá gốc là VND 2.565.000. Giá hiện tại là VND 923.400.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 17 --------------------
# hotel_info:  Hanoi Prime Center Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1,1km
# Chỗ nghỉ Du lịch Bền vững
# 8,9
# Tuyệt vời
# 1.776 đánh giá
# Địa điểm 9,3
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe 1 Giường đôi hoặc 2 Giường đơn với Cửa sổ
# Nhiều loại giường
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.790.000VND 590.700
# Giá gốc là VND 1.790.000. Giá hiện tại là VND 590.700.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 18 --------------------
# hotel_info:  Bao bữa sáng
# La Santé Hotel & Spa - by Bay Luxury
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 2,2km
# Chỗ nghỉ Du lịch Bền vững
# Vị trí cực tốt
# Mới trên Booking.com
# Phòng Deluxe
# 1 giường đôi cực lớn
# Bao bữa sáng
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 864.000
# Giá là VND 864.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 19 --------------------
# hotel_info:  Rising Dragon Estate Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# 7,7
# Tốt
# 895 đánh giá
# Ưu Đãi Sử Dụng Trong Ngày (giá trong ngày, sử dụng 3 giờ) - Phòng Superior
# 1 giường đôi hoặc 2 giường đơn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 170.100
# Giá là VND 170.100
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 20 --------------------
# hotel_info:  Hanoi Sena Hotel - Former Symphony Hanoi Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# 8,9
# Tuyệt vời
# 69 đánh giá
# Địa điểm 9,6
# Ưu Đãi Trong Thời Gian Có Hạn
# Phòng Superior Giường Đôi/2 Giường Đơn
# Nhiều loại giường
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 4.000.000VND 560.000
# Giá gốc là VND 4.000.000. Giá hiện tại là VND 560.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 21 --------------------
# hotel_info:  Singita Classy Boutique Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# Chỗ nghỉ Du lịch Bền vững
# 8,9
# Tuyệt vời
# 407 đánh giá
# Địa điểm 9,5
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi Nhìn Ra Thành Phố
# 1 giường đôi lớn
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.600.288VND 880.158
# Giá gốc là VND 1.600.288. Giá hiện tại là VND 880.158.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 22 --------------------
# hotel_info:  Bao bữa sáng
# Classic Street Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# Chỗ nghỉ Du lịch Bền vững
# 8,2
# Rất tốt
# 1.403 đánh giá
# Địa điểm 9,4
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# Bao bữa sáng
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 5.900.000VND 944.000
# Giá gốc là VND 5.900.000. Giá hiện tại là VND 944.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 23 --------------------
# hotel_info:  Hanoi Amorita Boutique Hotel & Travel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 400m
# Chỗ nghỉ Du lịch Bền vững
# 8,9
# Tuyệt vời
# 1.520 đánh giá
# Địa điểm 9,6
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 6.000.000VND 900.000
# Giá gốc là VND 6.000.000. Giá hiện tại là VND 900.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 24 --------------------
# hotel_info:  Hanoi Center Silk Charming Hotel & Travel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# Chỗ nghỉ Du lịch Bền vững
# 8,8
# Tuyệt vời
# 174 đánh giá
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi cực lớn
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 4.050.000VND 567.000
# Giá gốc là VND 4.050.000. Giá hiện tại là VND 567.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 25 --------------------
# 25
# hotel_info:  Bao bữa sáng
# Golden Sun Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 1.038 đánh giá
# Địa điểm 9,6
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi lớn
# Bao bữa sáng
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.620.000VND 972.000
# Giá gốc là VND 1.620.000. Giá hiện tại là VND 972.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 26 --------------------
# hotel_info:  Rex Hanoi Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# Chỗ nghỉ Du lịch Bền vững
# 8,9
# Tuyệt vời
# 280 đánh giá
# Địa điểm 9,6
# Ưu Đãi Mùa Du Lịch
# Phòng Superior Giường Đôi - Không có Cửa sổ
# 1 giường đôi cực lớn
# 1 đêm, 2 người lớn
# VND 5.360.000VND 1.340.000
# Giá gốc là VND 5.360.000. Giá hiện tại là VND 1.340.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 27 --------------------
# hotel_info:  Bao bữa sáng
# Marigold Hotel Hanoi
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1,4km
# Chỗ nghỉ Du lịch Bền vững
# 9,2
# Tuyệt hảo
# 480 đánh giá
# Phòng Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 595.034
# Giá là VND 595.034
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 28 --------------------
# hotel_info:  Bao bữa sáng
# L'Heritage Hotel Hanoi
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Chỗ nghỉ Du lịch Bền vững
# 9,3
# Tuyệt hảo
# 411 đánh giá
# Địa điểm 9,6
# Phòng Superior Giường Đôi/2 Giường Đơn
# Nhiều loại giường
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 1.366.043
# Giá là VND 1.366.043
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 29 --------------------
# hotel_info:  Hanoi Center Silk Boutique Hotel & Travel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,5km
# Chỗ nghỉ Du lịch Bền vững
# 9,0
# Tuyệt hảo
# 521 đánh giá
# Địa điểm 9,6
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi cực lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.450.000VND 857.500
# Giá gốc là VND 2.450.000. Giá hiện tại là VND 857.500.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 30 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi Emerald Waters Hotel Valley
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,5km
# Chỗ nghỉ Du lịch Bền vững
# 9,3
# Tuyệt hảo
# 1.297 đánh giá
# Địa điểm 9,7
# Phòng Deluxe Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 5 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.927.000VND 1.117.660
# Giá gốc là VND 1.927.000. Giá hiện tại là VND 1.117.660.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 31 --------------------
# hotel_info:  Bao bữa sáng
# Winter Boutique Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Chỗ nghỉ Du lịch Bền vững
# 8,4
# Rất tốt
# 322 đánh giá
# Địa điểm 9,3
# Ưu Đãi Mùa Du Lịch
# Phòng Superior Giường Đôi
# 1 giường đôi cực lớn
# Bao bữa sáng
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.330.000VND 532.000
# Giá gốc là VND 1.330.000. Giá hiện tại là VND 532.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 32 --------------------
# hotel_info:  Hanoi Eastern Gate Hostel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Vị trí cực tốt
# Mới trên Booking.com
# Phòng Ngủ Tập Thể 6 Giường Cho Cả Nam Và Nữ
# 1 phòng tập thể
# 6 giường đơn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 6 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 253.000
# Giá là VND 253.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 33 --------------------
# hotel_info:  MIA HOTEL
# Mở trong cửa sổ mới
# Quận Thanh Xuân, Hà NộiXem trên bản đồCách trung tâm 5,4km
# 7,7
# Tốt
# 115 đánh giá
# Phòng Deluxe - Sử Dụng Trong Ngày (2 Giờ)
# 1 giường đôi cực lớn
# Chỉ còn 7 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 765.000VND 382.500
# Giá gốc là VND 765.000. Giá hiện tại là VND 382.500.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 34 --------------------
# hotel_info:  Hanoi Garden Hotel & Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# 9,3
# Tuyệt hảo
# 263 đánh giá
# Địa điểm 9,8
# Phòng Deluxe 1 Giường đôi hoặc 2 Giường đơn với Cửa sổ
# 1 giường đôi hoặc 2 giường đơn
# 1 đêm, 2 người lớn
# VND 825.210
# Giá là VND 825.210
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 35 --------------------
# hotel_info:  Bao bữa sáng
# The Light Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,7km
# Chỗ nghỉ Du lịch Bền vững
# 8,7
# Tuyệt vời
# 404 đánh giá
# Địa điểm 9,4
# Phòng Superior Cozy Giường Đôi
# Nhiều loại giường
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 1.242.860
# Giá là VND 1.242.860
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 36 --------------------
# hotel_info:  Madelise Central Hotel & Travel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,7km
# Chỗ nghỉ Du lịch Bền vững
# 8,1
# Rất tốt
# 451 đánh giá
# Phòng Superior Có Giường Cỡ King
# 1 giường đôi lớn
# 1 đêm, 2 người lớn
# VND 1.947.500VND 681.625
# Giá gốc là VND 1.947.500. Giá hiện tại là VND 681.625.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 37 --------------------
# hotel_info:  Nature Hotel - Tran Thai Tong - Ha Noi
# Mở trong cửa sổ mới
# Cau Giay, Hà NộiXem trên bản đồCách trung tâm 6,4km
# 8,4
# Rất tốt
# 146 đánh giá
# Ưu Đãi Mùa Du Lịch
# Phòng Superior Có Giường Cỡ King
# 1 giường đôi cực lớn
# Bao bữa sáng
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.600.000VND 800.000
# Giá gốc là VND 1.600.000. Giá hiện tại là VND 800.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 38 --------------------
# hotel_info:  LUCK APART 8 - Hanoi Westlake Balcony Studio
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 6,7km
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 89 đánh giá
# Studio Tiêu Chuẩn
# 1 studio nguyên căn • 1 phòng tắm • 1 phòng bếp • 35m²
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 1 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.080.000VND 486.000
# Giá gốc là VND 1.080.000. Giá hiện tại là VND 486.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 39 --------------------
# hotel_info:  Golden Sun Hotel Trendy
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 450m
# Chỗ nghỉ Du lịch Bền vững
# 9,3
# Tuyệt hảo
# 308 đánh giá
# Địa điểm 9,8
# Ưu Đãi Mùa Du Lịch
# Suite Nhìn Ra Thành Phố
# 1 suite riêng tư
# 1 giường đôi cực lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 5 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.968.000VND 944.640
# Giá gốc là VND 1.968.000. Giá hiện tại là VND 944.640.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 40 --------------------
# hotel_info:  Beryl Signature Hotel & Travel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# Chỗ nghỉ Du lịch Bền vững
# 9,4
# Tuyệt hảo
# 202 đánh giá
# Địa điểm 9,6
# Phòng Deluxe Giường Đôi
# 1 giường đôi
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 5 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.975.000VND 892.500
# Giá gốc là VND 2.975.000. Giá hiện tại là VND 892.500.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 41 --------------------
# hotel_info:  Bao bữa sáng
# Hoàn Kiếm Lake View
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 450m
# Vị trí cực tốt
# Mới trên Booking.com
# Phòng Giường Đôi
# 3 giường (2 giường đơn, 1 giường đôi rất lớn)
# Bao bữa sáng
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 416.500
# Giá là VND 416.500
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 42 --------------------
# hotel_info:  Bao bữa sáng
# Hotel De Rond
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# Chỗ nghỉ Du lịch Bền vững
# 8,9
# Tuyệt vời
# 85 đánh giá
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Có Giường Cỡ Queen
# 1 giường đôi cực lớn
# Bao bữa sáng
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.472.000VND 912.640
# Giá gốc là VND 1.472.000. Giá hiện tại là VND 912.640.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 43 --------------------
# hotel_info:  Pullman Hanoi
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Đống Đa, Hà NộiXem trên bản đồCách trung tâm 2,5km
# 7,4
# Tốt
# 363 đánh giá
# Phòng Superior Có Giường Cỡ King Nhìn Ra Cảnh Thành Phố
# 1 giường đôi cực lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 1.900.000
# Giá là VND 1.900.000
# +VND 294.500 thuế và phí
# Xem chỗ trống
# ----------------- 44 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi Capital Premium Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 400m
# 9,1
# Tuyệt hảo
# 64 đánh giá
# Địa điểm 9,8
# Phòng Deluxe Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 6 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.500.000VND 750.000
# Giá gốc là VND 1.500.000. Giá hiện tại là VND 750.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 45 --------------------
# hotel_info:  Coco Hotel Cau Giay
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Cau Giay, Hà NộiXem trên bản đồCách trung tâm 5,2km
# Chỗ nghỉ Du lịch Bền vững
# 8,4
# Rất tốt
# 284 đánh giá
# Ưu Đãi Mùa Du Lịch
# Phòng Tiêu Chuẩn Giường Đôi
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 560.000VND 448.000
# Giá gốc là VND 560.000. Giá hiện tại là VND 448.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 46 --------------------
# hotel_info:  Lilyhome - Vinhomes D'Capitale 119 Tran Duy Hung
# Mở trong cửa sổ mới
# Cau Giay, Hà NộiXem trên bản đồCách trung tâm 6,3km
# Chỗ nghỉ Du lịch Bền vững
# Vị trí cực tốt
# Mới trên Booking.com
# Studio Có Ban Công
# 1 studio nguyên căn • 1 phòng tắm • 1 phòng bếp • 35m²
# 1 giường đôi lớn
# Chỉ còn 6 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.199.000
# Giá là VND 1.199.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 47 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi Lake View Hotel & Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 500m
# Chỗ nghỉ Du lịch Bền vững
# 9,4
# Tuyệt hảo
# 169 đánh giá
# Địa điểm 9,8
# Ưu Đãi Trong Thời Gian Có Hạn
# Phòng Superior Giường Đôi/2 Giường Đơn Không Có Cửa Sổ
# Nhiều loại giường
# Bao bữa sáng
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 5.300.000VND 795.000
# Giá gốc là VND 5.300.000. Giá hiện tại là VND 795.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 48 --------------------
# hotel_info:  Bao bữa sáng
# Luna House of the Old Quarter
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# Vị trí cực tốt
# Mới trên Booking.com
# Phòng Giường Đôi/2 Giường Đơn Có Phòng Tắm Riêng
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 618.000
# Giá là VND 618.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 49 --------------------
# hotel_info:  22Housing luxury Hotel & Residence 39 Linh Lang
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 4,4km
# Chỗ nghỉ Du lịch Bền vững
# 8,5
# Rất tốt
# 190 đánh giá
# Căn Hộ 1 Phòng Ngủ
# 1 căn hộ nguyên căn • 1 phòng ngủ • 1 phòng tắm • 1 phòng bếp • 30m² • 1 hồ bơi riêng
# 1 giường đôi cực lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 4 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 809.600VND 728.640
# Giá gốc là VND 809.600. Giá hiện tại là VND 728.640.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 50 --------------------
# 25
# hotel_info:  Bao bữa sáng
# Scent Premium Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 450m
# Chỗ nghỉ Du lịch Bền vững
# 9,5
# Xuất sắc
# 1.907 đánh giá
# Địa điểm 9,8
# Phòng Executive 3 Người
# 2 giường (1 giường đơn, 1 giường đôi lớn)
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 2.246.628
# Giá là VND 2.246.628
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 51 --------------------
# hotel_info:  Capital O 387 Bach Duong Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Cau Giay, Hà NộiXem trên bản đồCách trung tâm 6,6km
# Chỗ nghỉ Du lịch Bền vững
# 8,7
# Tuyệt vời
# 594 đánh giá
# Phòng Tiêu Chuẩn 2 Giường Đơn
# 2 giường đơn
# 1 đêm, 2 người lớn
# VND 339.282
# Giá là VND 339.282
# +VND 52.558 thuế và phí
# Xem chỗ trống
# ----------------- 52 --------------------
# hotel_info:  Bao bữa sáng
# Matilda Boutique Hotel & Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# Chỗ nghỉ Du lịch Bền vững
# 8,6
# Tuyệt vời
# 313 đánh giá
# Địa điểm 9,4
# Phòng Cổ Điển Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.966.500VND 865.260
# Giá gốc là VND 1.966.500. Giá hiện tại là VND 865.260.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 53 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi Siva Luxury Hotel & Travel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 693 đánh giá
# Địa điểm 9,6
# Tên Mới: Phòng Superior Giường Đôi/2 Giường Đơn Với Cửa Sổ Nhìn Ra Khu Vực Bên Trong Chỗ Nghỉ
# 1 giường đôi hoặc 2 giường đơn
# Bao bữa sáng
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 4.675.000VND 1.168.750
# Giá gốc là VND 4.675.000. Giá hiện tại là VND 1.168.750.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 54 --------------------
# hotel_info:  Cara Rustic Apartment
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 5,1km
# 9,8
# Xuất sắc
# 6 đánh giá
# Địa điểm 10
# Mới trên Booking.com
# Căn Hộ Superior
# 1 căn hộ nguyên căn • 2 phòng ngủ • 1 phòng khách • 2 phòng tắm • 80m²
# 3 giường (1 giường sofa, 2 giường đôi lớn)
# Chỉ còn 2 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.080.000
# Giá là VND 1.080.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 55 --------------------
# hotel_info:  Hanoi Golden Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# 7,9
# Tốt
# 521 đánh giá
# Phòng Superior Giường Đôi
# 1 giường đôi lớn
# 1 đêm, 2 người lớn
# VND 369.315
# Giá là VND 369.315
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 56 --------------------
# hotel_info:  An Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1,4km
# 8,9
# Tuyệt vời
# 396 đánh giá
# Địa điểm 9,4
# Phòng Tiêu chuẩn 2 Giường Đơn - Tầng Trệt
# 2 giường đơn
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 661.500VND 496.125
# Giá gốc là VND 661.500. Giá hiện tại là VND 496.125.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 57 --------------------
# hotel_info:  Golden Time Hostel 3
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,7km
# 8,3
# Rất tốt
# 610 đánh giá
# Địa điểm 9,4
# Phòng Cơ Bản 2 Giường Đơn Với Phòng Tắm Chung
# 2 giường đơn
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 384.000VND 345.600
# Giá gốc là VND 384.000. Giá hiện tại là VND 345.600.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 58 --------------------
# hotel_info:  Pan Pacific Hanoi
# Mở trong cửa sổ mới
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 2,8km
# Chỗ nghỉ Du lịch Bền vững
# 8,4
# Rất tốt
# 289 đánh giá
# Phòng Deluxe Giường Đôi
# 1 giường đôi cực lớn
# 1 đêm, 2 người lớn
# VND 2.874.642
# Giá là VND 2.874.642
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 59 --------------------
# hotel_info:  Mai Hotel
# Mở trong cửa sổ mới
# Quận Đống Đa, Hà NộiXem trên bản đồCách trung tâm 3km
# Chỗ nghỉ Du lịch Bền vững
# 8,6
# Tuyệt vời
# 172 đánh giá
# Phòng Superior Giường Đôi
# 1 giường đôi lớn
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 750.000VND 675.000
# Giá gốc là VND 750.000. Giá hiện tại là VND 675.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 60 --------------------
# hotel_info:  Mai Charming Hotel and Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,5km
# Chỗ nghỉ Du lịch Bền vững
# 7,8
# Tốt
# 382 đánh giá
# Phòng Superior Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# 1 đêm, 2 người lớn
# VND 459.884
# Giá là VND 459.884
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 61 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi Chic Boutique Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# Chỗ nghỉ Du lịch Bền vững
# 8,8
# Tuyệt vời
# 696 đánh giá
# Địa điểm 9,5
# Tiêu chuẩn - Không có cửa sổ
# 1 giường đôi
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 578.609
# Giá là VND 578.609
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 62 --------------------
# hotel_info:  Lotte Hotel Hanoi
# Mở trong cửa sổ mới
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 4,1km
# 9,0
# Tuyệt hảo
# 728 đánh giá
# Phòng Deluxe Có Giường Cỡ King
# 1 giường đôi cực lớn
# 1 đêm, 2 người lớn
# VND 2.432.224
# Giá là VND 2.432.224
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 63 --------------------
# hotel_info:  Chủ Nhật Homestay&Cafe - cơ sở 3 - 19 ngõ 194 Quán Thánh
# Mở trong cửa sổ mới
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 2,2km
# Chỗ nghỉ Du lịch Bền vững
# 9,4
# Tuyệt hảo
# 5 đánh giá
# Địa điểm 9,5
# Mới trên Booking.com
# Phòng Có Giường Cỡ King Với Ban Công
# 1 giường đôi lớn
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 660.000
# Giá là VND 660.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 64 --------------------
# hotel_info:  Serenity Villa Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 450m
# 8,3
# Rất tốt
# 416 đánh giá
# Ưu Đãi Sử Dụng Trong Ngày (giá trong ngày, sử dụng 7 giờ) - Phòng Deluxe
# 1 giường đôi
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 5 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 450.000
# Giá là VND 450.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 65 --------------------
# hotel_info:  Ancient Lane Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,7km
# 8,4
# Rất tốt
# 320 đánh giá
# Địa điểm 9,3
# Phòng Superior Giường Đôi/2 Giường Đơn Nhìn Ra Thành Phố
# 1 giường đôi hoặc 2 giường đơn
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 370.000
# Giá là VND 370.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 66 --------------------
# hotel_info:  Phuong li 2 homestay in Dinh Thon, My Dinh near kengnam
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Hà NộiXem trên bản đồCách trung tâm 8,1km
# 10
# Xuất sắc
# 2 đánh giá
# Địa điểm 10
# Mới trên Booking.com
# Căn Hộ 1 Phòng Ngủ
# 1 giường đôi
# 1 đêm, 2 người lớn
# VND 350.000
# Giá là VND 350.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 67 --------------------
# hotel_info:  DE LA SOIE Hotel & Travel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,5km
# Chỗ nghỉ Du lịch Bền vững
# 9,2
# Tuyệt hảo
# 324 đánh giá
# Địa điểm 9,8
# Ưu Đãi Trong Thời Gian Có Hạn
# Phòng Deluxe Giường Đôi
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 4.500.000VND 585.000
# Giá gốc là VND 4.500.000. Giá hiện tại là VND 585.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 68 --------------------
# hotel_info:  Cristina Center Hotel & Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Chỗ nghỉ Du lịch Bền vững
# 8,2
# Rất tốt
# 95 đánh giá
# Địa điểm 9,4
# Phòng Tiêu Chuẩn Giường Đôi
# 1 giường đôi lớn
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.251.000VND 487.890
# Giá gốc là VND 1.251.000. Giá hiện tại là VND 487.890.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 69 --------------------
# hotel_info:  MoonLight Tay Ho
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 2,9km
# 9,0
# Tuyệt hảo
# 202 đánh giá
# Ưu Đãi Mùa Du Lịch
# Căn Hộ 1 Phòng Ngủ
# 1 căn hộ nguyên căn • 1 phòng ngủ • 1 phòng tắm • 1 phòng bếp • 45m²
# 1 giường đôi cực lớn
# 1 đêm, 2 người lớn
# VND 1.200.000VND 720.000
# Giá gốc là VND 1.200.000. Giá hiện tại là VND 720.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 70 --------------------
# hotel_info:  Bao bữa sáng
# LUNA HOMESTAY room #2
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# Vị trí cực tốt
# Mới trên Booking.com
# Căn Hộ 1 Phòng Ngủ
# 1 giường đôi lớn
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 688.999
# Giá là VND 688.999
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 71 --------------------
# hotel_info:  Bao bữa sáng
# Hotel Emerald Waters Classy
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# Chỗ nghỉ Du lịch Bền vững
# 9,2
# Tuyệt hảo
# 737 đánh giá
# Địa điểm 9,7
# Phòng Tiêu Chuẩn Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 6 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.630.950VND 978.570
# Giá gốc là VND 1.630.950. Giá hiện tại là VND 978.570.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 72 --------------------
# hotel_info:  Bao bữa sáng
# Minerva Church Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 250m
# Chỗ nghỉ Du lịch Bền vững
# 9,0
# Tuyệt hảo
# 575 đánh giá
# Địa điểm 9,7
# Phòng Từ Công Ty Đối Tác
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 1.130.705
# Giá là VND 1.130.705
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 73 --------------------
# hotel_info:  Michi House Ngọc Hà đối diện Bảo tàng HCM
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 2,3km
# 9,2
# Tuyệt hảo
# 5 đánh giá
# Mới trên Booking.com
# Phòng Giường Đôi
# 1 giường đôi lớn
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 380.000
# Giá là VND 380.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 74 --------------------
# hotel_info:  La Renta Center Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# 9,7
# Xuất sắc
# 4 đánh giá
# Địa điểm 9,4
# Mới trên Booking.com
# Phòng Superior Giường Đôi
# 1 giường đôi
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 5 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.200.000VND 540.000
# Giá gốc là VND 1.200.000. Giá hiện tại là VND 540.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 75 --------------------
# 25
# hotel_info:  Ivy Hotel & Apartment
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Đống Đa, Hà NộiXem trên bản đồCách trung tâm 1,4km
# Chỗ nghỉ Du lịch Bền vững
# 8,4
# Rất tốt
# 15 đánh giá
# Địa điểm 9,3
# Mới trên Booking.com
# Căn Hộ Superior
# 1 căn hộ nguyên căn • 1 phòng ngủ • 1 phòng khách • 1 phòng tắm • 35m²
# 1 giường đôi lớn
# Chỉ còn 1 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.512.000VND 876.960
# Giá gốc là VND 1.512.000. Giá hiện tại là VND 876.960.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 76 --------------------
# hotel_info:  Moon West Lake Hotel & Residence
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 5km
# Chỗ nghỉ Du lịch Bền vững
# 8,2
# Rất tốt
# 383 đánh giá
# Ưu Đãi Mùa Du Lịch
# Căn Hộ Studio
# 1 căn hộ nguyên căn • 1 phòng ngủ • 1 phòng tắm • 1 phòng bếp • 15m²
# 1 giường đôi
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 4 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 825.000VND 660.000
# Giá gốc là VND 825.000. Giá hiện tại là VND 660.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 77 --------------------
# hotel_info:  Hanoi Exclusive Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# 9,1
# Tuyệt hảo
# 77 đánh giá
# Địa điểm 9,6
# Phòng Superior Giường Đôi/2 Giường Đơn
# Nhiều loại giường
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.498.500VND 824.175
# Giá gốc là VND 1.498.500. Giá hiện tại là VND 824.175.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 78 --------------------
# hotel_info:  HB Housing 228 AuCo
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 4,9km
# Chỗ nghỉ Du lịch Bền vững
# 6,3
# Điểm đánh giá
# 3 đánh giá
# Mới trên Booking.com
# Ưu Đãi Mùa Du Lịch
# Căn Hộ 2 Phòng Ngủ
# 1 căn hộ nguyên căn • 2 phòng ngủ • 1 phòng tắm • 60m²
# 3 giường (1 giường đôi, 2 giường đôi lớn)
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 595.000VND 446.250
# Giá gốc là VND 595.000. Giá hiện tại là VND 446.250.
# +VND 100.000 thuế và phí
# Xem chỗ trống
# ----------------- 79 --------------------
# hotel_info:  Bao bữa sáng
# La Mejor Hotel & Sky Bar
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,7km
# Chỗ nghỉ Du lịch Bền vững
# 9,3
# Tuyệt hảo
# 278 đánh giá
# Địa điểm 9,6
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.095.200VND 1.697.112
# Giá gốc là VND 2.095.200. Giá hiện tại là VND 1.697.112.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 80 --------------------
# hotel_info:  Bao bữa sáng
# Hôtel du LAC Hanoi
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 400m
# Chỗ nghỉ Du lịch Bền vững
# 9,3
# Tuyệt hảo
# 994 đánh giá
# Địa điểm 9,8
# Phòng Deluxe Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.880.000VND 1.728.000
# Giá gốc là VND 2.880.000. Giá hiện tại là VND 1.728.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 81 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi Royal Palace Hotel 2
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 411 đánh giá
# Địa điểm 9,6
# Phòng Superior Giường Đôi/2 Giường Đơn
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 5 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.550.000VND 790.500
# Giá gốc là VND 2.550.000. Giá hiện tại là VND 790.500.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 82 --------------------
# hotel_info:  Bao bữa sáng
# Diamond Nostalgia Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# 7,6
# Tốt
# 279 đánh giá
# Phòng Tiêu Chuẩn Giường Đôi/2 Giường Đơn
# Nhiều loại giường
# Bao bữa sáng
# Chỉ còn 7 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 900.000VND 495.000
# Giá gốc là VND 900.000. Giá hiện tại là VND 495.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 83 --------------------
# hotel_info:  Aura Passion Petals 71
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Vị trí cực tốt
# Mới trên Booking.com
# Phòng Giường Đôi Có Ban Công
# 1 giường đôi lớn
# Chỉ còn 1 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 390.000
# Giá là VND 390.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 84 --------------------
# hotel_info:  Milton Boutique Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# Chỗ nghỉ Du lịch Bền vững
# 8,1
# Rất tốt
# 122 đánh giá
# Ưu Đãi Mùa Du Lịch
# Phòng Tiêu Chuẩn Có Giường Cỡ King
# 1 giường đôi lớn
# 1 đêm, 2 người lớn
# VND 1.200.000VND 528.000
# Giá gốc là VND 1.200.000. Giá hiện tại là VND 528.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 85 --------------------
# hotel_info:  Bao bữa sáng
# FTE Ba Dinh Hotel
# Mở trong cửa sổ mới
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 4,8km
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 109 đánh giá
# Phòng Superior Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 1.377.000VND 1.170.450
# Giá gốc là VND 1.377.000. Giá hiện tại là VND 1.170.450.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 86 --------------------
# hotel_info:  Bao bữa sáng
# Babylon Grand Hotel & Spa
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 2km
# ...
# 1 giường đôi lớn
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 489.213
# Giá là VND 489.213
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1546 --------------------
# hotel_info:  B Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1,4km
# 8,7
# Tuyệt vời
# 40 đánh giá
# Phòng Tiêu Chuẩn Giường Đôi
# 1 giường đôi
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 830.000VND 747.000
# Giá gốc là VND 830.000. Giá hiện tại là VND 747.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1547 --------------------
# hotel_info:  Hanoi La Vision Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# 7,3
# Tốt
# 82 đánh giá
# Ưu Đãi Mùa Du Lịch
# Ưu Đãi Sử Dụng Trong Ngày (4 Giờ) - Phòng Superior Giường Đôi
# 1 giường đôi hoặc 2 giường đơn
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.100.000VND 352.000
# Giá gốc là VND 1.100.000. Giá hiện tại là VND 352.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1548 --------------------
# hotel_info:  Libré Homestay Đào Tấn
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Ba Đình, Hà NộiXem trên bản đồCách trung tâm 4,9km
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 217 đánh giá
# Địa điểm 9,3
# Ưu Đãi Trong Thời Gian Có Hạn
# Studio Tiêu Chuẩn
# 1 studio nguyên căn • 1 phòng tắm • 1 phòng bếp • 26m²
# 1 giường đôi lớn
# Chỉ còn 3 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 749.000VND 524.300
# Giá gốc là VND 749.000. Giá hiện tại là VND 524.300.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1549 --------------------
# hotel_info:  Aquarius Grand Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,5km
# Chỗ nghỉ Du lịch Bền vững
# 9,3
# Tuyệt hảo
# 124 đánh giá
# Địa điểm 9,7
# Phòng Superior Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 704.139
# Giá là VND 704.139
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1550 --------------------
# 25
# hotel_info:  Parklane Hanoi Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# 9,0
# Tuyệt hảo
# 33 đánh giá
# Địa điểm 9,8
# Mới trên Booking.com
# Phòng Superior Giường Đôi
# 1 giường đôi
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.698.370VND 849.185
# Giá gốc là VND 1.698.370. Giá hiện tại là VND 849.185.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1551 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi City Backpackers Hostel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# 8,5
# Rất tốt
# 1.053 đánh giá
# Địa điểm 9,5
# Giường Đôi trong Phòng ngủ Tập thể cho cả Nam và Nữ
# 1 giường trong phòng tập thể
# 1 giường đôi cực lớn
# Bao bữa sáng
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 5 giường với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 422.436VND 253.462
# Giá gốc là VND 422.436. Giá hiện tại là VND 253.462.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1552 --------------------
# hotel_info:  D'Capitale Serviced Apartment Trần Duy Hưng - FeriaVN Homes
# Mở trong cửa sổ mới
# Hà NộiXem trên bản đồCách trung tâm 6,3km
# Mới trên Booking.com
# Ưu Đãi Chỗ Nghỉ Mới
# Căn Hộ 1 Phòng Ngủ
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 1.280.000VND 1.024.000
# Giá gốc là VND 1.280.000. Giá hiện tại là VND 1.024.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1553 --------------------
# hotel_info:  Bao bữa sáng
# Hanoi Royal Palace Hotel 2
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 411 đánh giá
# Địa điểm 9,6
# Phòng Superior Giường Đôi/2 Giường Đơn
# 1 giường đôi lớn
# Bao bữa sáng
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 5.800.000VND 1.798.000
# Giá gốc là VND 5.800.000. Giá hiện tại là VND 1.798.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1554 --------------------
# hotel_info:  COSY HOUSE - CENTER'S TAY HO - CLOSE THE LAKE
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 5,1km
# Chỗ nghỉ Du lịch Bền vững
# 8,8
# Tuyệt vời
# 45 đánh giá
# Studio Có Ban Công
# 1 studio nguyên căn • 1 phòng tắm • 1 phòng bếp • 25m²
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 5 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 990.000VND 514.800
# Giá gốc là VND 990.000. Giá hiện tại là VND 514.800.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1555 --------------------
# hotel_info:  HB Housing 228 AuCo
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 4,9km
# Chỗ nghỉ Du lịch Bền vững
# 6,3
# Điểm đánh giá
# 3 đánh giá
# Mới trên Booking.com
# Ưu Đãi Mùa Du Lịch
# Căn Hộ 2 Phòng Ngủ
# 1 căn hộ nguyên căn • 2 phòng ngủ • 1 phòng tắm • 60m²
# 3 giường (1 giường đôi, 2 giường đôi lớn)
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 595.000VND 446.250
# Giá gốc là VND 595.000. Giá hiện tại là VND 446.250.
# +VND 100.000 thuế và phí
# Xem chỗ trống
# ----------------- 1556 --------------------
# hotel_info:  Bao bữa sáng
# Parosand Hanoi Hotel
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 6km
# 8,3
# Rất tốt
# 102 đánh giá
# Phòng Tiêu Chuẩn Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 652.519
# Giá là VND 652.519
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1557 --------------------
# hotel_info:  MK Premier Boutique Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,9km
# Chỗ nghỉ Du lịch Bền vững
# 8,3
# Rất tốt
# 146 đánh giá
# Địa điểm 9,4
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 1.002.360
# Giá là VND 1.002.360
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1558 --------------------
# hotel_info:  Airport Classic Hotel & Travel
# Mở trong cửa sổ mới
# Hà NộiXem trên bản đồCách trung tâm 19,8km
# 9,1
# Tuyệt hảo
# 367 đánh giá
# Phòng Superior Giường Đôi
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 571.725
# Giá là VND 571.725
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1559 --------------------
# hotel_info:  Holly's HideAway*City Center*Balcony*Netflix
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1,1km
# 8,5
# Rất tốt
# 2 đánh giá
# Địa điểm 10
# Mới trên Booking.com
# Căn Hộ 2 Phòng Ngủ
# 2 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 1 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 720.000
# Giá là VND 720.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1560 --------------------
# hotel_info:  Tunger Grand Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,8km
# Chỗ nghỉ Du lịch Bền vững
# 10
# Xuất sắc
# 3 đánh giá
# Địa điểm 10
# Mới trên Booking.com
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi Có Ban Công
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.444.000VND 1.222.000
# Giá gốc là VND 2.444.000. Giá hiện tại là VND 1.222.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1561 --------------------
# hotel_info:  Tunger Premium Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 500m
# Chỗ nghỉ Du lịch Bền vững
# 8,8
# Tuyệt vời
# 79 đánh giá
# Địa điểm 9,7
# Ưu Đãi Trong Thời Gian Có Hạn
# Phòng Deluxe Có Giường Cỡ Queen
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.667.000VND 750.150
# Giá gốc là VND 1.667.000. Giá hiện tại là VND 750.150.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1562 --------------------
# hotel_info:  Hanoi Emotion Hotel
# Mở trong cửa sổ mới
# Quận Đống Đa, Hà NộiXem trên bản đồCách trung tâm 1,9km
# Chỗ nghỉ Du lịch Bền vững
# 7,7
# Tốt
# 80 đánh giá
# Ưu Đãi Mùa Du Lịch
# Phòng Giường Đôi Hoặc 2 Giường Đơn Hạng Bình Dân
# 1 giường đôi lớn
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 3 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.350.000VND 810.000
# Giá gốc là VND 1.350.000. Giá hiện tại là VND 810.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1563 --------------------
# hotel_info:  PentStudio West Lake Hanoi
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 6,9km
# Chỗ nghỉ Du lịch Bền vững
# 8,9
# Tuyệt vời
# 182 đánh giá
# Căn Hộ Executive 1 Phòng Ngủ
# 1 căn hộ nguyên căn • 1 phòng ngủ • 1 phòng khách • 1 phòng tắm • 1 phòng bếp • 75m² • 1 hồ bơi riêng
# 1 giường đôi cực lớn
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 1.819.125
# Giá là VND 1.819.125
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1564 --------------------
# hotel_info:  Mercure Hanoi La Gare Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1,1km
# Chỗ nghỉ Du lịch Bền vững
# 8,2
# Rất tốt
# 137 đánh giá
# Phòng Tiêu Chuẩn Giường Đôi/2 Giường Đơn
# 1 giường đôi hoặc 2 giường đơn
# 1 đêm, 2 người lớn
# VND 1.350.000
# Giá là VND 1.350.000
# +VND 209.250 thuế và phí
# Xem chỗ trống
# ----------------- 1565 --------------------
# hotel_info:  Bao bữa sáng
# Five Star Westlake 1st-4th Floors Hotel & Serviced Apartment
# Mở trong cửa sổ mới
# Hà NộiXem trên bản đồCách trung tâm 3,7km
# 9,5
# Xuất sắc
# 453 đánh giá
# Ưu Đãi Mùa Du Lịch
# Phòng Deluxe Giường Đôi
# 1 giường đôi lớn
# Bao bữa sáng
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 4 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.400.000VND 1.608.000
# Giá gốc là VND 2.400.000. Giá hiện tại là VND 1.608.000.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1566 --------------------
# hotel_info:  OYO 276 Bh Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Chỗ nghỉ Du lịch Bền vững
# 8,3
# Rất tốt
# 267 đánh giá
# Phòng Tiêu Chuẩn Giường Đôi
# 1 giường đôi lớn
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 297.517
# Giá là VND 297.517
# +VND 46.223 thuế và phí
# Xem chỗ trống
# ----------------- 1567 --------------------
# hotel_info:  Bao bữa sáng
# Bendecir Hotel & Spa
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 500m
# Chỗ nghỉ Du lịch Bền vững
# 9,1
# Tuyệt hảo
# 1.873 đánh giá
# Địa điểm 9,7
# Phòng Premier 2 Giường đơn
# 2 giường đơn
# Bao bữa sáng
# 1 đêm, 2 người lớn
# VND 1.639.627
# Giá là VND 1.639.627
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1568 --------------------
# hotel_info:  Hanoi Pomihoa Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 0,6km
# 7,2
# Tốt
# 5 đánh giá
# Phòng Superior Giường Đôi
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 795.000VND 715.500
# Giá gốc là VND 795.000. Giá hiện tại là VND 715.500.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1569 --------------------
# hotel_info:  Jacayl Hotel TCG
# Mở trong cửa sổ mới
# Cau Giay, Hà NộiXem trên bản đồCách trung tâm 6,4km
# Chỗ nghỉ Du lịch Bền vững
# 8,7
# Tuyệt vời
# 3 đánh giá
# Phòng Có Giường Cỡ King
# 1 giường đôi cực lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 5 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 1.423.125VND 1.067.344
# Giá gốc là VND 1.423.125. Giá hiện tại là VND 1.067.344.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1570 --------------------
# hotel_info:  Margaery Boutique Apartment
# Mở trong cửa sổ mới
# Quận Tây Hồ, Hà NộiXem trên bản đồCách trung tâm 4,2km
# Chỗ nghỉ Du lịch Bền vững
# 8,5
# Rất tốt
# 114 đánh giá
# Căn Hộ - Tầng Trệt
# 1 căn hộ nguyên căn • 1 phòng ngủ • 1 phòng khách • 1 phòng tắm • 1 phòng bếp • 80m²
# 3 giường (1 giường đôi, 1 giường đôi rất lớn, 1 giường sofa)
# Chỉ còn 1 căn với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.520.000VND 1.360.800
# Giá gốc là VND 2.520.000. Giá hiện tại là VND 1.360.800.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1571 --------------------
# hotel_info:  Hola House Hanoi
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Chỗ nghỉ Du lịch Bền vững
# 9,3
# Tuyệt hảo
# 3 đánh giá
# Mới trên Booking.com
# Phòng Giường Đôi Với Phòng Tắm Chung
# 1 giường đôi lớn
# Miễn Phí hủy phòng • Không cần thanh toán trước
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# Chỉ còn 2 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 435.000
# Giá là VND 435.000
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1572 --------------------
# hotel_info:  Bao bữa sáng
# Carillon Boutique Hotel
# Mở trong cửa sổ mới
# Nổi bật
# Chỗ nghỉ này trả phí cao hơn để được hiển thị nhiều hơn trên trang của chúng tôi. Đây là nơi phù hợp với tiêu chí tìm kiếm và là lựa chọn tuyệt vời dành cho bạn.
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1km
# Chỗ nghỉ Du lịch Bền vững
# 9,0
# Tuyệt hảo
# 141 đánh giá
# Địa điểm 9,6
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 1 giường đôi lớn
# Bao bữa sáng
# Miễn phí hủy
# Bạn có thể hủy sau, nên hãy đặt ngay hôm nay để có giá tốt.
# 1 đêm, 2 người lớn
# VND 734.641
# Giá là VND 734.641
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1573 --------------------
# hotel_info:  HNC Premier Hotel & Residences
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 1,4km
# Chỗ nghỉ Du lịch Bền vững
# 9,0
# Tuyệt hảo
# 191 đánh giá
# Studio Tiêu Chuẩn
# 1 studio nguyên căn • 1 phòng tắm • 1 phòng bếp • 35m²
# 1 giường đôi lớn
# 1 đêm, 2 người lớn
# VND 902.640
# Giá là VND 902.640
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1574 --------------------
# hotel_info:  Galliot Central Hotel
# Mở trong cửa sổ mới
# Quận Hoàn Kiếm, Hà NộiXem trên bản đồCách trung tâm 350m
# 8,1
# Rất tốt
# 109 đánh giá
# Phòng Deluxe Giường Đôi/2 Giường Đơn
# 3 giường (2 giường đơn, 1 giường đôi)
# Chỉ còn 6 phòng với giá này trên trang của chúng tôi
# 1 đêm, 2 người lớn
# VND 2.223.600VND 667.080
# Giá gốc là VND 2.223.600. Giá hiện tại là VND 667.080.
# Đã bao gồm thuế và phí
# Xem chỗ trống
# ----------------- 1575 --------------------

# %%
date_ends = ['2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28']
for d in range(0,7):
    print (date_ends[d])
# Out:
# 2023-05-22
# 2023-05-23
# 2023-05-24
# 2023-05-25
# 2023-05-26
# 2023-05-27
# 2023-05-28
